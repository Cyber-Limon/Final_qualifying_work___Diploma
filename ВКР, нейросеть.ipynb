# %% [markdown]
# # ВЫПУСКНАЯ КВАЛИФИКАЦИОННАЯ РАБОТА (ВКР)
# ## Математическое и программное обеспечение для прогнозирования свойств медицинских композиционных материалов

# %% [markdown]
# ### Импорт библиотек:
# - "pandas"     -
# - "sklearn"    - :
# - "tensorflow" - :

# %%
import numpy  as np
import pandas as pd

from tensorflow              import keras
from sklearn.preprocessing   import StandardScaler
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Загрузка данных:
# - "compound"   - массив составов сплавов
# - "properties" - массив свойств сплавов

# %%
compound   = pd.read_excel("ВКР, датасет.xlsx", usecols="B:V")
compound   = compound.values.tolist()
compound   = np.array(compound)

properties = pd.read_excel("ВКР, датасет.xlsx", usecols="W:AD")
properties = properties.values.tolist()
properties = np.array(properties)

# %% [markdown]
# ### Разделение данных на тренировочную и тестовую выборки:
# - "X_train" - тренировочные составы
# - "X_test"  - тестовые составы
# - "y_train" - тренировочные свойства
# - "y_test"  - тестовые свойства

# %%
X_train, X_test, y_train, y_test = train_test_split(
    compound,
    properties,
    test_size=0.2,
    random_state=1107,
    shuffle=True
)

# %% [markdown]
# ### Нормализация данных

# %%
scaler_X = StandardScaler()
X_train  = scaler_X.fit_transform(X_train)
X_test   = scaler_X.transform(X_test)

scaler_Y = StandardScaler()
y_train  = scaler_Y.fit_transform(y_train)
y_test   = scaler_Y.transform(y_test)

# %% [markdown]
# ### Архитектура модели

# %%
model = keras.Sequential([
    keras.Input(shape=(X_train.shape[1],)),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(y_train.shape[1])
])

# %% [markdown]
# ### Обучение модели

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

model.summary()

log = model.fit(
    X_train, y_train,
    batch_size=32,
    epochs=100,
    validation_split=0.2,
    verbose=1
)
# Out:
# Model: "sequential_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_181 (Dense)               │ (None, 512)            │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_182 (Dense)               │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_183 (Dense)               │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_184 (Dense)               │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_185 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_186 (Dense)               │ (None, 8)              │           264 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 186,088 (726.91 KB)
#  Trainable params: 186,088 (726.91 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.1714 - loss: 0.9953 - val_accuracy: 0.2500 - val_loss: 1.0400
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2857 - loss: 0.9107 - val_accuracy: 0.3056 - val_loss: 1.0124
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3000 - loss: 0.8450 - val_accuracy: 0.3333 - val_loss: 0.9886
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3000 - loss: 0.7816 - val_accuracy: 0.3333 - val_loss: 0.9761
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3357 - loss: 0.7216 - val_accuracy: 0.3889 - val_loss: 0.9768
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3429 - loss: 0.6623 - val_accuracy: 0.3333 - val_loss: 0.9745
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3929 - loss: 0.6188 - val_accuracy: 0.3333 - val_loss: 0.9738
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3857 - loss: 0.5772 - val_accuracy: 0.3056 - val_loss: 0.9930
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3929 - loss: 0.5369 - val_accuracy: 0.3056 - val_loss: 0.9632
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4643 - loss: 0.5232 - val_accuracy: 0.3611 - val_loss: 0.9835
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3714 - loss: 0.4812 - val_accuracy: 0.4444 - val_loss: 0.9713
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4000 - loss: 0.4459 - val_accuracy: 0.3333 - val_loss: 0.9760
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4429 - loss: 0.4226 - val_accuracy: 0.3333 - val_loss: 0.9782
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4857 - loss: 0.3887 - val_accuracy: 0.3056 - val_loss: 0.9968
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4643 - loss: 0.3671 - val_accuracy: 0.2222 - val_loss: 0.9879
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5071 - loss: 0.3475 - val_accuracy: 0.3333 - val_loss: 0.9539
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5000 - loss: 0.3241 - val_accuracy: 0.2778 - val_loss: 1.0271
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5071 - loss: 0.3123 - val_accuracy: 0.2778 - val_loss: 0.9866
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.